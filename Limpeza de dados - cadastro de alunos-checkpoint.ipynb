# %%
import pandas as pd

# %%
cadastro = pd.read_excel(r'C:/Users/carol/Downloads/alunos.xlsx',sheet_name='cadastro')

# %%
cadastro.head()
# Out:
#    ID_aluno                email Aniversario TokenAluno          Atividades
# 0         1   gustavo@gmail.com   21.11.2005        M1A             Esporte
# 1         2     miguel@gmail.com  20.06.2005        M1I                 NaN
# 2         3   fernanda@gmail.com  26.11.2005        F1A            Cultural
# 3         5      lucas@gmail.com  26.08.2006       M1AR             Esporte
# 4         4      vitor@gmail.com  02.12.2006        M1A  Esporte / Cultural

# %%
cadastro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_aluno     15 non-null     int64
#  1   email        15 non-null     object
#  2   Aniversario  15 non-null     object
#  3   TokenAluno   15 non-null     object
#  4   Atividades   11 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 728.0+ bytes

# %%
cadastro[~cadastro.email.str.contains('@')]
# Out:
#     ID_aluno              email Aniversario TokenAluno          Atividades
# 13        14  roberta%gmail.com  09.05.2006        F1A  Esporte / Cultural

# %%
cadastro.loc[cadastro.ID_aluno == 14]
# Out:
#     ID_aluno              email Aniversario TokenAluno          Atividades
# 13        14  roberta%gmail.com  09.05.2006        F1A  Esporte / Cultural

# %%
cadastro.loc[cadastro.ID_aluno == 14,'email'] = 'roberta@gmail.com'

# %%
cadastro[~cadastro.email.str.contains('@')]
# Out:
# Empty DataFrame
# Columns: [ID_aluno, email, Aniversario, TokenAluno, Atividades]
# Index: []

# %%
cadastro['email'] = cadastro.email.str.lower()

# %%
cadastro.email
# Out:
# 0      gustavo@gmail.com
# 1        miguel@gmail.com
# 2      fernanda@gmail.com
# 3         lucas@gmail.com
# 4         vitor@gmail.com
# 5         aline@gmail.com
# 6        pedro @gmail.com
# 7          lara@gmail.com
# 8       antonio@gmail.com
# 9           lua@gmail.com
# 10       thiago@gmail.com
# 11     priscila@gmail.com
# 12      vitoria@gmail.com
# 13      roberta@gmail.com
# 14       carlos@gmail.com
# Name: email, dtype: object

# %%
cadastro.email.str.replace(' ','')
# Out:
# 0      gustavo@gmail.com
# 1       miguel@gmail.com
# 2     fernanda@gmail.com
# 3        lucas@gmail.com
# 4        vitor@gmail.com
# 5        aline@gmail.com
# 6        pedro@gmail.com
# 7         lara@gmail.com
# 8      antonio@gmail.com
# 9          lua@gmail.com
# 10      thiago@gmail.com
# 11    priscila@gmail.com
# 12     vitoria@gmail.com
# 13     roberta@gmail.com
# 14      carlos@gmail.com
# Name: email, dtype: object

# %%
cadastro['email'] = cadastro.email.str.replace(' ','')

# %%
cadastro.Aniversario
# Out:
# 0     21.11.2005
# 1     20.06.2005
# 2     26.11.2005
# 3     26.08.2006
# 4     02.12.2006
# 5     20.12.2005
# 6     09.09.2006
# 7     05.07.2006
# 8     07.08.2005
# 9     04.06.2006
# 10    27.11.2006
# 11    06.04.2006
# 12    18.03.2005
# 13    09.05.2006
# 14    24.07.2006
# Name: Aniversario, dtype: object

# %%
cadastro['Aniversario'] = pd.to_datetime(cadastro.Aniversario,format='%d.%m.%Y')

# %%
cadastro['genero'] = cadastro.TokenAluno.str[0]

# %%
cadastro['mensalista'] = cadastro.TokenAluno.str.get(1)

# %%
cadastro['atividade'] = cadastro.TokenAluno.str.get(2)

# %%
cadastro['reprovado'] = cadastro.TokenAluno.str.get(3)

# %%
cadastro
# Out:
#     ID_aluno               email Aniversario TokenAluno          Atividades  \
# 0          1   gustavo@gmail.com  2005-11-21        M1A             Esporte
# 1          2    miguel@gmail.com  2005-06-20        M1I                 NaN
# 2          3  fernanda@gmail.com  2005-11-26        F1A            Cultural
# 3          5     lucas@gmail.com  2006-08-26       M1AR             Esporte
# 4          4     vitor@gmail.com  2006-12-02        M1A  Esporte / Cultural
# 5          6     aline@gmail.com  2005-12-20        F1A                 NaN
# 6          7     pedro@gmail.com  2006-09-09        M1A             Esporte
# 7          8      lara@gmail.com  2006-07-05        F0A            Cultural
# 8          9   antonio@gmail.com  2005-08-07        M1A            Cultural
# 9         10       lua@gmail.com  2006-06-04        M1A                 NaN
# 10        11    thiago@gmail.com  2006-11-27        M1A  Esporte / Cultural
# 11        12  priscila@gmail.com  2006-04-06        F0I            Cultural
# 12        13   vitoria@gmail.com  2005-03-18       F1AR             Esporte
# 13        14   roberta@gmail.com  2006-05-09        F1A  Esporte / Cultural
# 14        15    carlos@gmail.com  2006-07-24        M1A                 NaN
#
#    genero mensalista atividade reprovado
# 0       M          1         A       NaN
# 1       M          1         I       NaN
# 2       F          1         A       NaN
# 3       M          1         A         R
# 4       M          1         A       NaN
# 5       F          1         A       NaN
# 6       M          1         A       NaN
# 7       F          0         A       NaN
# 8       M          1         A       NaN
# 9       M          1         A       NaN
# 10      M          1         A       NaN
# 11      F          0         I       NaN
# 12      F          1         A         R
# 13      F          1         A       NaN
# 14      M          1         A       NaN

# %%
cadastro['reprovado'] = cadastro.reprovado.fillna('N')

# %%
cadastro
# Out:
#     ID_aluno               email Aniversario TokenAluno          Atividades  \
# 0          1   gustavo@gmail.com  2005-11-21        M1A             Esporte
# 1          2    miguel@gmail.com  2005-06-20        M1I                 NaN
# 2          3  fernanda@gmail.com  2005-11-26        F1A            Cultural
# 3          5     lucas@gmail.com  2006-08-26       M1AR             Esporte
# 4          4     vitor@gmail.com  2006-12-02        M1A  Esporte / Cultural
# 5          6     aline@gmail.com  2005-12-20        F1A                 NaN
# 6          7     pedro@gmail.com  2006-09-09        M1A             Esporte
# 7          8      lara@gmail.com  2006-07-05        F0A            Cultural
# 8          9   antonio@gmail.com  2005-08-07        M1A            Cultural
# 9         10       lua@gmail.com  2006-06-04        M1A                 NaN
# 10        11    thiago@gmail.com  2006-11-27        M1A  Esporte / Cultural
# 11        12  priscila@gmail.com  2006-04-06        F0I            Cultural
# 12        13   vitoria@gmail.com  2005-03-18       F1AR             Esporte
# 13        14   roberta@gmail.com  2006-05-09        F1A  Esporte / Cultural
# 14        15    carlos@gmail.com  2006-07-24        M1A                 NaN
#
#    genero mensalista atividade reprovado
# 0       M          1         A         N
# 1       M          1         I         N
# 2       F          1         A         N
# 3       M          1         A         R
# 4       M          1         A         N
# 5       F          1         A         N
# 6       M          1         A         N
# 7       F          0         A         N
# 8       M          1         A         N
# 9       M          1         A         N
# 10      M          1         A         N
# 11      F          0         I         N
# 12      F          1         A         R
# 13      F          1         A         N
# 14      M          1         A         N

# %%
cadastro['Esporte'] = cadastro.Atividades.str.contains('Esporte',na=False)

# %%
cadastro['Cultural'] = cadastro.Atividades.str.contains('Cultural',na=False)

# %%
cadastro
# Out:
#     ID_aluno               email Aniversario TokenAluno          Atividades  \
# 0          1   gustavo@gmail.com  2005-11-21        M1A             Esporte
# 1          2    miguel@gmail.com  2005-06-20        M1I                 NaN
# 2          3  fernanda@gmail.com  2005-11-26        F1A            Cultural
# 3          5     lucas@gmail.com  2006-08-26       M1AR             Esporte
# 4          4     vitor@gmail.com  2006-12-02        M1A  Esporte / Cultural
# 5          6     aline@gmail.com  2005-12-20        F1A                 NaN
# 6          7     pedro@gmail.com  2006-09-09        M1A             Esporte
# 7          8      lara@gmail.com  2006-07-05        F0A            Cultural
# 8          9   antonio@gmail.com  2005-08-07        M1A            Cultural
# 9         10       lua@gmail.com  2006-06-04        M1A                 NaN
# 10        11    thiago@gmail.com  2006-11-27        M1A  Esporte / Cultural
# 11        12  priscila@gmail.com  2006-04-06        F0I            Cultural
# 12        13   vitoria@gmail.com  2005-03-18       F1AR             Esporte
# 13        14   roberta@gmail.com  2006-05-09        F1A  Esporte / Cultural
# 14        15    carlos@gmail.com  2006-07-24        M1A                 NaN
#
#    genero mensalista atividade reprovado  Esporte  Cultural
# 0       M          1         A         N     True     False
# 1       M          1         I         N    False     False
# 2       F          1         A         N    False      True
# 3       M          1         A         R     True     False
# 4       M          1         A         N     True      True
# 5       F          1         A         N    False     False
# 6       M          1         A         N     True     False
# 7       F          0         A         N    False      True
# 8       M          1         A         N    False      True
# 9       M          1         A         N    False     False
# 10      M          1         A         N     True      True
# 11      F          0         I         N    False      True
# 12      F          1         A         R     True     False
# 13      F          1         A         N     True      True
# 14      M          1         A         N    False     False

# %%
cadastro['Esporte'] = cadastro.Esporte.apply(lambda x:1 if x  else 0)

# %%
cadastro['Cultural'] = cadastro.Cultural.apply(lambda x:1 if x  else 0)

# %%
cadastro
# Out:
#     ID_aluno               email Aniversario TokenAluno          Atividades  \
# 0          1   gustavo@gmail.com  2005-11-21        M1A             Esporte
# 1          2    miguel@gmail.com  2005-06-20        M1I                 NaN
# 2          3  fernanda@gmail.com  2005-11-26        F1A            Cultural
# 3          5     lucas@gmail.com  2006-08-26       M1AR             Esporte
# 4          4     vitor@gmail.com  2006-12-02        M1A  Esporte / Cultural
# 5          6     aline@gmail.com  2005-12-20        F1A                 NaN
# 6          7     pedro@gmail.com  2006-09-09        M1A             Esporte
# 7          8      lara@gmail.com  2006-07-05        F0A            Cultural
# 8          9   antonio@gmail.com  2005-08-07        M1A            Cultural
# 9         10       lua@gmail.com  2006-06-04        M1A                 NaN
# 10        11    thiago@gmail.com  2006-11-27        M1A  Esporte / Cultural
# 11        12  priscila@gmail.com  2006-04-06        F0I            Cultural
# 12        13   vitoria@gmail.com  2005-03-18       F1AR             Esporte
# 13        14   roberta@gmail.com  2006-05-09        F1A  Esporte / Cultural
# 14        15    carlos@gmail.com  2006-07-24        M1A                 NaN
#
#    genero mensalista atividade reprovado  Esporte  Cultural
# 0       M          1         A         N        1         0
# 1       M          1         I         N        0         0
# 2       F          1         A         N        0         1
# 3       M          1         A         R        1         0
# 4       M          1         A         N        1         1
# 5       F          1         A         N        0         0
# 6       M          1         A         N        1         0
# 7       F          0         A         N        0         1
# 8       M          1         A         N        0         1
# 9       M          1         A         N        0         0
# 10      M          1         A         N        1         1
# 11      F          0         I         N        0         1
# 12      F          1         A         R        1         0
# 13      F          1         A         N        1         1
# 14      M          1         A         N        0         0

# %%
cadastro = cadastro.drop(['TokenAluno','Atividades'],axis=1)

# %%
cadastro
# Out:
#     ID_aluno               email Aniversario genero mensalista atividade  \
# 0          1   gustavo@gmail.com  2005-11-21      M          1         A
# 1          2    miguel@gmail.com  2005-06-20      M          1         I
# 2          3  fernanda@gmail.com  2005-11-26      F          1         A
# 3          5     lucas@gmail.com  2006-08-26      M          1         A
# 4          4     vitor@gmail.com  2006-12-02      M          1         A
# 5          6     aline@gmail.com  2005-12-20      F          1         A
# 6          7     pedro@gmail.com  2006-09-09      M          1         A
# 7          8      lara@gmail.com  2006-07-05      F          0         A
# 8          9   antonio@gmail.com  2005-08-07      M          1         A
# 9         10       lua@gmail.com  2006-06-04      M          1         A
# 10        11    thiago@gmail.com  2006-11-27      M          1         A
# 11        12  priscila@gmail.com  2006-04-06      F          0         I
# 12        13   vitoria@gmail.com  2005-03-18      F          1         A
# 13        14   roberta@gmail.com  2006-05-09      F          1         A
# 14        15    carlos@gmail.com  2006-07-24      M          1         A
#
#    reprovado  Esporte  Cultural
# 0          N        1         0
# 1          N        0         0
# 2          N        0         1
# 3          R        1         0
# 4          N        1         1
# 5          N        0         0
# 6          N        1         0
# 7          N        0         1
# 8          N        0         1
# 9          N        0         0
# 10         N        1         1
# 11         N        0         1
# 12         R        1         0
# 13         N        1         1
# 14         N        0         0
